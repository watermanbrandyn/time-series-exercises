# %% [markdown]
# # Seaborn Warmup Exercise

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Use seaborn to create the following visualizations:
#
# 1. Make a barplot of the average horsepower by origin. Add the keyword argument `ci=None`. What does this change?
# 1. Make a scatterplot of displacement vs horsepower. Add the keyword argument `hue='weight'`. What does this change? Add the keyword argument `palette='Greens'`. What does this change?
# 1. Make a scatterplot of displacement vs mpg. Add the keyword argument `hue='cylinders'`. What does this change? Add the line of code below in a seperate cell, run it, and then create your scatterplot again. What does this change?
#
#     ```python
#     df.cylinders = df.cylinders.astype('category')
#     ```

# %%
# 1. Barplot
sns.barplot(x='origin', y='horsepower', data=df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
# 1. Barplot
horse = sns.barplot(x='origin', y='horsepower', data=df, ci=None)
horse.set(xlabel='Origin', ylabel='Horsepower', title='Horsepower by Origin')
None

# %%
# ci keyword determines size of confidence interval to draw around predicted values

# %% [markdown]
# 2. Make a scatterplot of displacement vs horsepower. Add the keyword argument hue='weight'. What does this change? Add the keyword argument palette='Greens'. What does this change?

# %%
sns.scatterplot(x='displacement', y='horsepower', data=df)
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %%
sns.scatterplot(x='displacement', y='horsepower', data=df, hue='weight')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %%
sns.scatterplot(x='displacement', y='horsepower', data=df, hue='weight', palette='Greens')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %%
# Hue applies another column to categorize data with (in this case a continuous column), palette changes the 
# color scheme for this

# %% [markdown]
# 3. Make a scatterplot of displacement vs mpg. Add the keyword argument hue='cylinders'. What does this change? Add the line of code below in a seperate cell, run it, and then create your scatterplot again. What does this change?

# %%
sns.scatterplot(x='mpg', y='displacement', data=df)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.scatterplot(x='mpg', y='displacement', data=df, hue='cylinders')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.scatterplot(x='mpg', y='displacement', data=df, hue='cylinders', palette='tab10')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
df.cylinders = df.cylinders.astype('category')

# %%
sns.scatterplot(data=df, y='mpg', x='displacement', hue='cylinders')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
sns.relplot(data=df, y='mpg', x='displacement', col='origin', row='cylinders')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13,7))
sns.scatterplot(data=df, y='mpg', x='displacement', ax=ax1)
sns.scatterplot(data=df, y='mpg', x='weight', ax=ax2)

ax1.set(title='Diplacement v MPG')
ax2.set(title='Weight v MPG')
fig.suptitle('Cars MPG Viz')
# Out:
# Text(0.5, 0.98, 'Cars MPG Viz')
